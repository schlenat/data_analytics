# %% [markdown]
# # Importing and preparing supermarkets data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import fnmatch
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Get current working directory
print('Current working directory:', os.getcwd())

# Show .json files in the current working directory
flist = fnmatch.filter(os.listdir('.'), '*.json')
for i in flist:
    print(i)
# Out:
# Current working directory: /workspaces/data_analytics/Week_02
# supermarkets.json

# %% [markdown]
# ## Importing data

# %%
# Read the data to a pandas data frame
df1 = pd.read_json('supermarkets.json', encoding='utf-8')
df1.head(5)
# Out:
#    type        id        lat       lon  \
# 0  node  33126515  47.155616  9.037915
# 1  node  36726161  47.226191  8.980329
# 2  node  39768209  47.225069  8.969981
# 3  node  39947904  47.376732  8.542161
# 4  node  48932835  47.375020  8.522895
#
#                                                 tags
# 0  {'brand': 'Spar', 'brand:wikidata': 'Q610492',...
# 1  {'addr:city': 'Uznach', 'addr:housenumber': '2...
# 2  {'addr:city': 'Uznach', 'addr:postcode': '8730...
# 3  {'addr:city': 'Zürich', 'addr:country': 'CH', ...
# 4  {'addr:city': 'Zürich', 'addr:housenumber': '7...

# %% [markdown]
# ## Count number of rows and columns in the data frame

# %%
# Dimension (rows, columns)
print('Dimension:', df1.shape)

# Number of rows
print('Number of rows:', df1.shape[0])

# Number of columns
print('Number of columns:', df1.shape[1])
# Out:
# Dimension: (3392, 5)
# Number of rows: 3392
# Number of columns: 5

# %% [markdown]
# ## Column 'tags' is a pandas Series with dictionaries -> change to data frame

# %%
# Type of the first item of column tags
print(type(df1.tags))
print(type(df1.tags[0]))

# Content of the first item of column tags
print(df1.tags[0].keys())

# Change to data frame
df2 = pd.DataFrame.from_records(df1.tags)
df2 = df2[['brand', 'shop', 'addr:city', 'addr:street', 'addr:housenumber', 'addr:postcode', 'opening_hours']]

# Rename selected columns
df2 = df2.rename(columns={'addr:city': 'city',
                          'addr:street':'street',
                          'addr:housenumber': 'housenumber',
                          'addr:postcode': 'postcode',
                          'opening_hours': 'hours'})


# Show first records of data frame
df2.head()
# Out:
# <class 'pandas.core.series.Series'>
# <class 'dict'>
# dict_keys(['brand', 'brand:wikidata', 'brand:wikipedia', 'name', 'opening_hours', 'shop'])
#     brand         shop    city          street housenumber postcode  \
# 0    Spar  supermarket     NaN             NaN         NaN      NaN
# 1  Migros  supermarket  Uznach  Zürcherstrasse          25     8730
# 2    Coop  supermarket  Uznach             NaN         NaN     8730
# 3    Coop  supermarket  Zürich   Bahnhofbrücke           1     8001
# 4  Migros  supermarket  Zürich    Wengistrasse           7     8004
#
#                                                hours
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                NaN
# 3                                  Mo-Sa 06:00-22:00
# 4                          Mo-Sa 08:00-21:00; PH off

# %% [markdown]
# ## Merge df1 and df2

# %%
# Merge df and df2
df = pd.merge(df1[['type', 'id', 'lat', 'lon']], 
              df2[['brand', 'shop', 'city', 'street', 'housenumber', 'postcode', 'hours']],
              left_index=True, 
              right_index=True)
df.head(5)
# Out:
#    type        id        lat       lon   brand         shop    city  \
# 0  node  33126515  47.155616  9.037915    Spar  supermarket     NaN
# 1  node  36726161  47.226191  8.980329  Migros  supermarket  Uznach
# 2  node  39768209  47.225069  8.969981    Coop  supermarket  Uznach
# 3  node  39947904  47.376732  8.542161    Coop  supermarket  Zürich
# 4  node  48932835  47.375020  8.522895  Migros  supermarket  Zürich
#
#            street housenumber postcode  \
# 0             NaN         NaN      NaN
# 1  Zürcherstrasse          25     8730
# 2             NaN         NaN     8730
# 3   Bahnhofbrücke           1     8001
# 4    Wengistrasse           7     8004
#
#                                                hours
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                NaN
# 3                                  Mo-Sa 06:00-22:00
# 4                          Mo-Sa 08:00-21:00; PH off

# %% [markdown]
# ## Count and identify the number of missing values (if any)

# %%
# Count missing values
print(pd.isna(df).sum())

# Identify rows with missing values, e.g.:
df.loc[pd.isna(df['city'])]
# Out:
# type              0
# id                0
# lat               0
# lon               0
# brand          1065
# shop              0
# city           1777
# street         1608
# housenumber    1680
# postcode       1709
# dtype: int64
#       type           id        lat       lon   brand         shop city street  \
# 0     node     33126515  47.155616  9.037915    Spar  supermarket  NaN    NaN
# 5     node     60271452  47.406671  9.305450     NaN  supermarket  NaN    NaN
# 6     node     70656485  47.491253  8.733981     NaN  supermarket  NaN    NaN
# 10    node     81321513  47.532917  9.066408   Landi  supermarket  NaN    NaN
# 13    node     95582038  47.050385  9.059214     NaN  supermarket  NaN    NaN
# ...    ...          ...        ...       ...     ...          ...  ...    ...
# 3384  node  11083317088  46.862184  9.531169    Lidl  supermarket  NaN    NaN
# 3386  node  11098091830  46.205111  6.130174    Coop  supermarket  NaN    NaN
# 3387  node  11099817248  46.928691  7.561873     NaN  supermarket  NaN    NaN
# 3388  node  11103235832  46.166742  8.771970  Migros  supermarket  NaN    NaN
# 3391  node  11129298207  47.537518  7.608581    Coop  supermarket  NaN    NaN
#
#      housenumber postcode
# 0            NaN      NaN
# 5            NaN      NaN
# 6            NaN      NaN
# 10           NaN      NaN
# 13           NaN      NaN
# ...          ...      ...
# 3384         NaN      NaN
# 3386         NaN      NaN
# 3387         NaN      NaN
# 3388         NaN      NaN
# 3391         NaN      NaN
#
# [1777 rows x 10 columns]

# %% [markdown]
# ## Count and identify duplicated values (if any)

# %%
# Count duplicated values
print(df.duplicated().sum())

# Identify rows with duplicated values, e.g.:
df[df[['id']].duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [type, id, lat, lon, brand, shop, city, street, housenumber, postcode]
# Index: []

# %% [markdown]
# ## Get data types of all variables

# %%
# Get data types (note that in pandas, a string is referred to as 'object')
df.dtypes
# Out:
# type            object
# id               int64
# lat            float64
# lon            float64
# brand           object
# shop            object
# city            object
# street          object
# housenumber     object
# postcode        object
# dtype: object

# %% [markdown]
# ## Additional filters on supermarkets

# %%
df_filtered = df.loc[(df['brand'] == 'Coop') & (df['city'] == 'Zürich')]
df_coop_cities = df.loc[(df['brand'] == 'Coop') & (df['city'].isin(['Zürich', 'Basel', 'Bern']))]

coop_count = df_coop_cities.shape[0]
print('Number of Coop stores in Zürich:', df_filtered.shape[0])
df_full_address = df.loc[df['brand'].notna() & df['city'].notna() & df['housenumber'].notna() & df['postcode'].notna()]
print('Number of stores with full address:', df_full_address.shape[0])

df_dict = df.to_dict()
print(df_dict['hours'])

df_migros_zurich = df.loc[(df['brand'] == 'Migros') & (df['city'] == 'Zürich')]
print("Migros supermarkets in Zürich (head):")
df_migros_zurich.head()
# Out:
# Number of Coop stores in Zürich: 37
# Number of stores with full address: 1148
# {0: 'Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00', 1: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17:00; PH off', 2: nan, 3: 'Mo-Sa 06:00-22:00', 4: 'Mo-Sa 08:00-21:00; PH off', 5: nan, 6: nan, 7: 'Mo-Fr 07:30-20:00; PH off; Sa 08:00-19:00', 8: 'Mo-Sa 07:30-21:00', 9: 'Mo-Sa 07:30-21:00', 10: 'Mo-Sa 08:00-12:00, 13:30-18:00', 11: 'Mo-Sa 07:30-21:00; PH off', 12: nan, 13: 'Mo-Su 09:00-21:00;PH off', 14: 'Mo-Fr 07:30-13:00, 19:00-19:00; Sa 07:30-16:00', 15: nan, 16: 'Mo-Sa 09:00-20:00; PH off', 17: nan, 18: 'Mo-Sa 08:00-20:00', 19: 'Mo-Sa 08:00-20:00; PH off', 20: 'Mo-Sa 07:30-20:00', 21: nan, 22: 'Mo-Fr 07:00-19:00; Sa 07:00-17:00', 23: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 08:00-18:00; PH off', 24: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 08:00-17:00; PH off', 25: nan, 26: 'Mo-Th 07:30-19:00; Fr 07:30-21:00; Sa 07:30-17:00; Su off; PH off', 27: nan, 28: 'Mo-Th 08:00-20:00; Sa 07:30-17:00; Su off; PH off; Fr 08:00-21:00', 29: 'Mo-Fr 08:00-19:00, Sa 08:00-18:00; PH off', 30: nan, 31: 'Mo-Fr 08:30-20:00, Sa 08:00-18:00; PH off', 32: 'Mo-Sa 08:00-20:00', 33: 'Mo-Sa 08:00-19:00', 34: 'Mo-Fr 07:30-18:30; Sa 07:30-17:00', 35: 'Mo-Sa 07:30-20:00; Su 09:30-18:00', 36: 'Mo-Fr 07:30-12:00,14:00-18:30; Sa 07:30-16:00; PH off', 37: nan, 38: 'Mo-Fr 07:00-18:30;Sa 07:00-17:00', 39: nan, 40: 'Mo-Fr 07:00-20:00; Sa 07:00-19:00', 41: nan, 42: 'Mo-Fr 08:00-19:00, Sa 08:00-18:00; PH off', 43: 'Mo-Fr 08:00-20:00; Sa 08:00-18:00; Su,PH closed', 44: nan, 45: nan, 46: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 08:00-17:00; PH off', 47: nan, 48: nan, 49: 'Mo-Fr 08:00-19:00; Sa 08:00-17:00', 50: 'Mo-Fr 06:30-22:00; PH,Sa-Su 08:00-22:00', 51: nan, 52: 'Mo-Sa 07:00-20:00; PH off', 53: 'Mo-Sa 06:30-21:00', 54: 'Mo-Fr 07:00-20:00, Sa 07:00-18:00', 55: 'Mo-Fr 09:00-21:00; Sa 08:00-21:00', 56: nan, 57: 'mo-fr 8:30-18:30; sa 8:00-17:00', 58: 'Mo-Sa 07:00-21:00', 59: 'Mo-Fr 07:30-21:00; Sa 07:30-20:00', 60: nan, 61: 'Mo-Fr 07:00-20:00; Sa 07:00-17:00; PH closed', 62: 'Mo-Sa 08:00-20:00; PH off', 63: 'Mo-Sa 07:00-22:00', 64: 'Mo 08:00-17:00; Tu-Th 08:00-19:00; Fr 08:00-20:00; Sa 07:30-17:00; Su,PH off', 65: nan, 66: 'Mo-Fr 07:00-20:00; Sa 07:00-19:00', 67: 'Mo-Sa 08:00-20:00; PH off', 68: nan, 69: 'Mo-Sa 07:30-21:00', 70: 'Mo-Fr 06:00-20:00; Sa 08:00-20:00', 71: 'Mo-Sa 07:30-20:00; PH off', 72: 'Mo-Sa 07:30-21:00', 73: 'Mo-Fr 07:30-20:00; Sa 07:30-18:00', 74: 'Mo-Fr 07:30-19:00; Sa 07:30-18:00; Su 09:00-18:00', 75: 'Mo-Fr 08:00-20:00; Sa 08:00-19:00', 76: 'Mo-Sa 08:00-20:00; PH off', 77: 'Mo-Su 06:00-22:00', 78: nan, 79: nan, 80: nan, 81: 'Mo-Sa 07:00-22:00', 82: 'Mo-Sa 07:30-20:00; PH off', 83: 'Mo-Fr 07:00-20:00, Sa 08:00-20:00; PH off', 84: 'Mo-Sa 06:00-22:00; Su 07:00-22:00', 85: 'Mo-Sa 08:00-20:00; PH off', 86: 'Mo-Sa 08:00-21:00', 87: 'Mo-Sa 06:00-22:00, Su 07:00-22:00', 88: 'Mo-Th 08:00-19:00;Fr 08:00-21:00;Sa 07:30-16:00;Su off', 89: 'Mo-Sa 08:00-20:00; PH off', 90: 'Mo-Th 8:00-19:00;Fr 8:00-20:00;Sa 8:00-18:00', 91: 'Mo-Fr 08:00-20:00; Sa 07:30-20:00', 92: 'Mo-Fr 08:00-19:00, Sa 07:30-18:00; PH off', 93: nan, 94: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 08:00-18:00; PH off', 95: 'Mo-Sa 08:00-21:00', 96: 'Mo-Sa 08:00-20:00', 97: 'Mo-Fr 08:00-19:00; Th 08:00-21:00; Sa 07:30-17:00; PH off', 98: 'Mo-Fr 08:00-20:00; Sa 07:30-20:00', 99: 'Mo-Fr 08:00-20:00; Sa 07:30-20:00', 100: 'Mo-Fr 08:00-19:00; Sa 08:00-17:00', 101: nan, 102: 'Mo-Fr 07:00-19:00; Sa 07:00-17:00', 103: 'Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 08:00-17:00; PH off', 104: 'Mo-Fr 06:30-12:30,14:00-18:30; Sa 07:15-17:00; Su 08:00-12:00', 105: 'Mo-Fr 08:00-19:00, Sa 08:00-18:00; PH off', 106: 'Mo-Fr 08:00-20:00; Sa 08:00-18:00', 107: 'Mo-Sa 06:00-20:00; PH closed', 108: 'Mo-Th 07:30-19:00; Fr 07:30-20:00; Sa 07:30-17:00', 109: 'Mo-Fr 08:00-20:00, Sa 08:00-17:00; PH off', 110: 'Mo-Fr 08:00-19:00; Sa 08:00-17:00; Su,PH closed', 111: nan, 112: 'Mo-Sa 07:00-20:00', 113: nan, 114: 'Mo-Sa 08:00-21:00; Su 09:00-20:00', 115: nan, 116: 'Mo-Fr 08:00-19:00; Sa 08:00-18:00', 117: 'Mo-Fr 8:00-19:00;Sa 8:00-17: ...
# Migros supermarkets in Zürich (head):
#     type         id        lat       lon   brand         shop    city  \
# 4   node   48932835  47.375020  8.522895  Migros  supermarket  Zürich
# 11  node   83330862  47.344749  8.529981  Migros  supermarket  Zürich
# 16  node  119249170  47.375255  8.536107  Migros  supermarket  Zürich
# 50  node  262400822  47.364072  8.530945  Migros  supermarket  Zürich
# 71  node  267346993  47.385598  8.531471  Migros  supermarket  Zürich
#
#            street housenumber postcode  \
# 4    Wengistrasse           7     8004
# 11   Etzelstrasse           3     8038
# 16   Löwenstrasse       31-35     8001
# 50  Tessinerplatz          10     8002
# 71  Limmatstrasse         152     8005
#
#                                       hours
# 4                 Mo-Sa 08:00-21:00; PH off
# 11                Mo-Sa 07:30-21:00; PH off
# 16                Mo-Sa 09:00-20:00; PH off
# 50  Mo-Fr 06:30-22:00; PH,Sa-Su 08:00-22:00
# 71                Mo-Sa 07:30-20:00; PH off

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('supermarkets_data_prepared.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1014-azure
# Datetime: 2024-10-01 11:19:02
# Python Version: 3.11.10
# -----------------------------------
